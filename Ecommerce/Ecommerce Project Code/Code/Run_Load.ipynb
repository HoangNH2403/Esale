# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from notebookutils import mssparkutils
# Out:
# StatementMeta(, ee706e90-be5e-4fcb-9ac7-65c53a3f1e5d, 3, Finished, Available)

# %%
mssparkutils.fs.mount("abfss://MyProject@onelake.dfs.fabric.microsoft.com/Project_Lakehouse.Lakehouse/Files","/Files")
# Out:
# StatementMeta(, ee706e90-be5e-4fcb-9ac7-65c53a3f1e5d, 4, Finished, Available)
# SynapseWidget(Synapse.DataFrame, a9725c81-0ff9-4723-a088-45f1d4f28f36)
# True

# %%
mssparkutils.fs.getMountPath("/Files")
# Out:
# StatementMeta(, ee706e90-be5e-4fcb-9ac7-65c53a3f1e5d, 5, Finished, Available)
# '/synfs/notebook/ee706e90-be5e-4fcb-9ac7-65c53a3f1e5d/Files'

# %%
check_files=mssparkutils.fs.ls(f"file://{mssparkutils.fs.getMountPath('/Files')}/Current/")
# Out:
# StatementMeta(, ee706e90-be5e-4fcb-9ac7-65c53a3f1e5d, 6, Finished, Available)

# %%
if check_files:
    mssparkutils.notebook.run("Bronze_Sales")
    mssparkutils.notebook.run("Gold_Customer")
    mssparkutils.notebook.run("Gold_Date")
    mssparkutils.notebook.run("Gold_Product")
    mssparkutils.notebook.run("Gold_Shipmode")
    mssparkutils.notebook.run("Gold_OrderPriority")
    mssparkutils.notebook.run("Gold_OrderReturn")
    mssparkutils.notebook.run("Gold_Fact_Sale")
    mssparkutils.notebook.run("Archive_Files")
# Out:
# StatementMeta(, ee706e90-be5e-4fcb-9ac7-65c53a3f1e5d, 8, Finished, Available)
